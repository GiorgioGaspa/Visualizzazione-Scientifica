# %%
import pandas as pd

# Specifica il percorso del file
file_path = 'C:/Users/user/Desktop/Popularity of Programming Languages from 2004 to 2024.csv'

# Carica il file CSV
try:
    data = pd.read_csv(file_path)
    #print(data.head())  # Visualizza le prime righe del dataset
except Exception as e:
    print(f"Errore nel caricamento del file: {e}")

# Mostra informazioni sul dataset
#print(data.info())

# Visualizza le prime righe del dataset
data.head()

#https://www.kaggle.com/datasets/muhammadkhalid/most-popular-programming-languages-since-2004/code    link dataset
# Out:
#              Date  Abap   Ada  C/C++    C#  Cobol  Dart  Delphi/Pascal   Go  \
# 0       July 2004  0.34  0.36  10.01  4.68   0.42   0.0           2.80  0.0
# 1     August 2004  0.35  0.36   9.74  4.96   0.46   0.0           2.65  0.0
# 2  September 2004  0.41  0.41   9.59  5.04   0.51   0.0           2.64  0.0
# 3    October 2004  0.40  0.38   9.47  5.29   0.53   0.0           2.76  0.0
# 4   November 2004  0.38  0.38   9.48  5.22   0.55   0.0           2.75  0.0
#
#    Groovy  ...  Powershell  Python     R  Ruby  Rust  Scala  Swift  \
# 0    0.03  ...        0.16    2.51  0.39  0.33  0.24   0.17    0.0
# 1    0.07  ...        0.15    2.62  0.40  0.40  0.19   0.17    0.0
# 2    0.08  ...        0.08    2.71  0.40  0.41  0.17   0.13    0.0
# 3    0.09  ...        0.12    2.91  0.42  0.46  0.12   0.14    0.0
# 4    0.07  ...        0.12    2.83  0.41  0.44  0.17   0.15    0.0
#
#    TypeScript   VBA  Visual Basic
# 0         0.0  1.43          8.50
# 1         0.0  1.45          8.51
# ...

# %%
import matplotlib.pyplot as plt


data['Date'] = pd.to_datetime(data['Date'])

data.set_index('Date', inplace=True)


df_selected = data[['Java', 'Python', 'JavaScript', 'C/C++','C#','Cobol','Dart','Delphi/Pascal','Go','Groovy','R','Ruby','Rust','Scala','Swift','VBA']]

plt.figure(figsize=(12, 8))
plt.plot(df_selected)
plt.title('Programming Language Popularity (July 2004 - September 2024)')
plt.xlabel('Date')
plt.ylabel('Popularity')
plt.legend(['Java', 'Python', 'JavaScript', 'C/C++','C#','Cobol','Dart','Delphi/Pascal','Go','Groovy','R','Ruby','Rust','Scala','Swift','VBA'])
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

repo = pd.read_csv('C:/Users/user/Desktop/repos.csv')

top_languages = repo.nlargest(20, 'num_repos')


plt.figure(figsize=(12, 8))
plt.bar(top_languages['language'], top_languages['num_repos'], color='skyblue')
plt.xlabel('Programming Languages')
plt.ylabel('Number of Repositories')
plt.title('Top 20 Programming Languages by Number of Repositories on GitHub')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()  # Adjusts the plot to ensure everything fits without overlapping
plt.show()

#https://www.kaggle.com/datasets/isaacwen/github-programming-languages-data/data link dataset

# %%
survey = pd.read_csv('C:/Users/user/Desktop/survey_results_public.csv')
survey.head()
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# ...

# %%
salary2023 = pd.read_csv('C:/Users/user/Desktop/ds_salaries2023.csv')
salary2024 = pd.read_csv('C:/Users/user/Desktop/Dataset salary 2024.csv')

avg_salary_2023 = salary2023['salary_in_usd'].mean()
avg_salary_2024 = salary2024['salary_in_usd'].mean()

years = ['2023', '2024']
avg_salaries = [avg_salary_2023, avg_salary_2024]

plt.figure(figsize=(10, 6))
plt.bar(years, avg_salaries)
plt.xlabel('Anno')
plt.ylabel('Stipendio Medio in USD')
plt.title('Comparazione Stipendio Medio: 2023 vs 2024')
plt.show()

# %%
#https://www.kaggle.com/datasets/arnabchaki/data-science-salaries-2023
#https://www.kaggle.com/datasets/zeesolver/data-eng-salary-2024

avg_salary_by_experience_2023 = salary2023.groupby('experience_level')['salary_in_usd'].mean().reset_index()
avg_salary_by_experience_2024 = salary2024.groupby('experience_level')['salary_in_usd'].mean().reset_index()

avg_salary_by_experience = pd.merge(avg_salary_by_experience_2023, avg_salary_by_experience_2024, on='experience_level', suffixes=('_2023', '_2024'))

plt.figure(figsize=(10, 6))
bar_width = 0.35
index = range(len(avg_salary_by_experience))

plt.bar(index, avg_salary_by_experience['salary_in_usd_2023'], bar_width, label='2023')
plt.bar([i + bar_width for i in index], avg_salary_by_experience['salary_in_usd_2024'], bar_width, label='2024')

plt.xlabel('Livello di Esperienza')
plt.ylabel('Stipendio Medio in USD')
plt.title('Stipendi Medi per Livello di Esperienza: 2023 vs 2024')
plt.xticks([i + bar_width/2 for i in index], avg_salary_by_experience['experience_level'])
plt.legend()
plt.tight_layout()
plt.show()

# %%
df= pd.read_csv('C:/Users/user/Desktop/cybersecurity_attacks.csv')

df['Timestamp'] = pd.to_datetime(df['Timestamp'])

df.set_index('Timestamp', inplace=True)

attack_frequency_until_2022 = df[df.index <= '2022-12-31'].resample('M').size()

plt.figure(figsize=(12, 6))
plt.plot(attack_frequency_until_2022, marker='o')
plt.title('Frequenza degli Attacchi Informatici nel Tempo')
plt.xlabel('Data')
plt.ylabel('Numero di Attacchi')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

#https://www.kaggle.com/datasets/teamincribo/cyber-security-attacks/code link dataset

# %%
severity_counts = df['Severity Level'].value_counts()

plt.figure(figsize=(12, 6))
severity_counts.plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=['lightcoral', 'gold', 'skyblue'])
plt.title('Distribuzione della Severità degli Attacchi')
plt.ylabel('')
plt.tight_layout()
plt.show()

# %%
action_taken_counts = df['Action Taken'].value_counts()

plt.figure(figsize=(12, 6))
action_taken_counts.plot(kind='bar', color='lightcoral')
plt.title('Azioni Intrapprese in Risposta agli Attacchi')
plt.xlabel('Azione')
plt.ylabel('Numero di Attacchi')
plt.grid(True, axis='y')
plt.tight_layout()
plt.show()

# %%
df_new = pd.read_csv('C:/Users/user/Desktop/cyber-operations-incidents.csv')

df_new['Date'] = pd.to_datetime(df_new['Date'])

df_new['Year'] = df_new['Date'].dt.year

incidents_per_year_category = df_new.groupby(['Year', 'Category']).size().unstack().fillna(0)

incidents_per_year_category.plot(kind='bar', stacked=True, figsize=(14, 7))
plt.title('Numero di Incidenti per Anno e Categoria')
plt.xlabel('Anno')
plt.ylabel('Numero di Incidenti')
plt.legend(title='Categoria')
plt.grid(True, axis='y')
plt.tight_layout()
plt.show()

# %%
type_counts = df_new['Type'].value_counts()

plt.figure(figsize=(12, 6))
type_counts.plot(kind='bar', color='lightblue')
plt.title('Numero di Incidenti per Tipo di Attacco')
plt.xlabel('Tipo di Attacco')
plt.ylabel('Numero di Incidenti')
plt.grid(True, axis='y')
plt.tight_layout()
plt.show()

# %%
data_jobs_df = pd.read_csv('C:/Users/user/Desktop/jobs_in_data.csv')

average_salary_by_category = data_jobs_df.groupby('job_category')['salary_in_usd'].mean().reset_index()

average_salary_by_category.columns = ['Job Category', 'Average Salary in USD']


plt.figure(figsize=(12, 8))
plt.barh(average_salary_by_category['Job Category'], average_salary_by_category['Average Salary in USD'], color='#6495ED')
plt.xlabel('Stipendio Medio in USD')
plt.ylabel('Categoria di Lavoro')
plt.title('Stipendio Medio per Categoria di Lavoro')
plt.gca().invert_yaxis()  # Invert y-axis to have the highest salary at the top
plt.grid(axis='x', linestyle='--', alpha=0.7)

for index, value in enumerate(average_salary_by_category['Average Salary in USD']):
    plt.text(value, index, f'{value:.0f}', va='center', ha='left', color='black')

plt.show()

# %%
most_common_jobs = data_jobs_df['job_title'].value_counts().reset_index()
most_common_jobs.columns = ['Job Title', 'Count']

top_10_common_jobs = most_common_jobs.head(10)

top_10_common_jobs['Percentage'] = (top_10_common_jobs['Count'] / top_10_common_jobs['Count'].sum()) * 100

plt.figure(figsize=(12, 8))
plt.barh(top_10_common_jobs['Job Title'], top_10_common_jobs['Percentage'], color='#87CEEB')
plt.xlabel('Percentuale di Posizioni (%)')
plt.ylabel('Titolo di Lavoro')
plt.title('I 10 Lavori Più Richiesti nel Settore dei Dati (Percentuale)')
plt.gca().invert_yaxis()  # Invert y-axis to have the highest percentage at the top
plt.grid(axis='x', linestyle='--', alpha=0.7)

for index, value in enumerate(top_10_common_jobs['Percentage']):
    plt.text(value, index, f'{value:.2f}%', va='center', ha='left', color='black')

plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6480\830940901.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_10_common_jobs['Percentage'] = (top_10_common_jobs['Count'] / top_10_common_jobs['Count'].sum()) * 100

# %%
data1 = pd.read_csv('C:/Users/user/Desktop/big_tech_stock_prices.csv')

data1['date'] = pd.to_datetime(data1['date'])

selected_companies = ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'META']  # Apple, Microsoft, Google, Amazon, Meta (Facebook)
subset_data = data1[data1['stock_symbol'].isin(selected_companies)]

pivot_data = subset_data.pivot(index='date', columns='stock_symbol', values='close')

plt.figure(figsize=(14, 8))
for company in selected_companies:
    plt.plot(pivot_data.index, pivot_data[company], label=company)

plt.title('Prezzi di Chiusura delle Principali Aziende Tech (2010 - Presente)')
plt.xlabel('Data')
plt.ylabel('Prezzo di Chiusura')
plt.legend(title='Azienda')
plt.grid(True)
plt.show()

#https://www.kaggle.com/datasets/umerhaddii/big-tech-giants-stock-price-data

# %%
import pandas as pd
import matplotlib.pyplot as plt

linkedin_data = pd.read_csv('C:/Users/user/Desktop/linkdin.csv')


skills_columns = linkedin_data.columns[11:]

if 'PYTHON' in linkedin_data.columns:
    skills_columns = list(skills_columns) + ['PYTHON']

skills_counts_corrected = linkedin_data[skills_columns].sum()

plt.figure(figsize=(14, 8))
skills_counts_corrected.sort_values().plot(kind='barh', color='skyblue')
plt.title('Competenze richieste nelle offerte di lavoro', fontsize=16)
plt.xlabel('Numero di offerte di lavoro', fontsize=14)
plt.ylabel('Competenze', fontsize=14)
plt.grid(axis='x')

plt.show()

#https://www.kaggle.com/datasets/joebeachcapital/linkedin-jobs

# %%
most_requested_jobs = linkedin_data.groupby('Designation')['Total_applicants'].sum().sort_values(ascending=False).head(10)


plt.figure(figsize=(12, 8))
plt.pie(most_requested_jobs, labels=most_requested_jobs.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title('Lavori più richiesti', fontsize=16)
plt.axis('equal') 

plt.show()

# %%
#https://www.kaggle.com/datasets/mrcalvinwhite/technology-perception-survey

# %%
data = pd.read_csv('C:/Users/user/Desktop/Dataset - Factors Influencing Technology Adoption in Consumer Households.csv')

import matplotlib.pyplot as plt

# Visualizzazione: Frequenza d'Uso delle Tecnologie per Gruppo di Età
age_bins = [0, 20, 30, 40, 50, 60, 70, 100]
age_labels = ['0-20', '21-30', '31-40', '41-50', '51-60', '61-70', '71+']
data['GruppoEtà'] = pd.cut(data['Age'], bins=age_bins, labels=age_labels)

plt.figure(figsize=(12, 8))
for tech in ['Frequency_LaptopDesktop', 'Frequency_Smartphone', 'Frequency_Tablet']:
    plt.plot(data.groupby('GruppoEtà')[tech].mean(), label=tech)
    
plt.title('Frequenza Media d\'Uso delle Tecnologie per Gruppo di Età')
plt.xlabel('Gruppo di Età')
plt.ylabel('Frequenza Media')
plt.legend()
plt.grid(True)
plt.show()

# Visualizzazione: Barriere all'Adozione
barriers = ['Barrier_HighPrice', 'Barrier_TechKnowledge', 'Barrier_PrivacySecurity', 'Barrier_ReliableInternet', 'Barrier_ChangeReluctance']
barrier_means = data[barriers].mean()

plt.figure(figsize=(10, 6))
barrier_means.plot(kind='bar', color='salmon', edgecolor='black')
plt.title('Livello Medio delle Barriere all\'Adozione della Tecnologia')
plt.xlabel('Barriera')
plt.ylabel('Livello Medio della Barriera')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
# Visualizzazione: Percentuale di Uso dei Vari Apparecchi Elettronici


frequency_columns = ['Frequency_LaptopDesktop', 'Frequency_Smartphone', 'Frequency_Tablet', 'Frequency_SmartHomeDevices', 'Frequency_WearableDevices', 'Frequency_GamingConsoles']
frequency_data = data[frequency_columns]


frequency_percentages = frequency_data.apply(lambda x: x.value_counts(normalize=True) * 100)

plt.figure(figsize=(14, 8))

for column in frequency_columns:
    plt.plot(frequency_percentages.index, frequency_percentages[column], marker='o', label=column)

plt.title('Percentuale di Uso dei Vari Apparecchi Elettronici')
plt.xlabel('Frequenza di Uso')
plt.ylabel('Percentuale')
plt.legend()
plt.grid(True)
plt.show()

# %%
percentuali_frequenze = frequency_data.apply(lambda x: x.value_counts(normalize=True) * 100).fillna(0)

percentuali_frequenze.plot(kind='bar', figsize=(14, 8), edgecolor='black')

plt.title('Percentuale di Uso dei Vari Apparecchi Elettronici')
plt.xlabel('Frequenza di Uso')
plt.ylabel('Percentuale')
plt.legend(title='Dispositivo Elettronico', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.xticks(rotation=0)
plt.show()

# %%
plt.figure(figsize=(12, 8))
plt.boxplot([data[data['GruppoEtà'] == age_group]['LikelinessToRecommend'].dropna() for age_group in age_labels], labels=age_labels)
plt.title('Propensione a Raccomandare in base all\'Età')
plt.xlabel('Gruppo di Età')
plt.ylabel('Propensione a Raccomandare')
plt.grid(True)
plt.show()

# %%
correlation_data = data[['Barrier_HighPrice', 'Barrier_TechKnowledge', 'Barrier_PrivacySecurity', 'Barrier_ReliableInternet', 'Barrier_ChangeReluctance', 'LikelinessToRecommend']].corr()

plt.figure(figsize=(10, 8))
plt.imshow(correlation_data, cmap='coolwarm', interpolation='none', aspect='auto')
plt.colorbar()
plt.xticks(range(len(correlation_data.columns)), correlation_data.columns, rotation=45)
plt.yticks(range(len(correlation_data.columns)), correlation_data.columns)
plt.title('Correlazione tra Barriere e Propensione a Raccomandare')
plt.show()

# %%
import seaborn as sns

# Visualizzazione: Correlazione tra Barriere e Propensione a Raccomandare


correlation_data = data[['Barrier_HighPrice', 'Barrier_TechKnowledge', 'Barrier_PrivacySecurity', 'Barrier_ReliableInternet', 'Barrier_ChangeReluctance', 'LikelinessToRecommend']].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_data, annot=True, cmap='coolwarm', center=0, linewidths=.5, cbar_kws={'label': 'Correlazione'})
plt.title('Correlazione tra Barriere e Propensione a Raccomandare')
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.show()
